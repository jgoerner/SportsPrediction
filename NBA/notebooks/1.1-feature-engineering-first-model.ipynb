# %% [markdown]
# # Feature Generation
# This notebooks contains the feature engineering for the first model iteration (see [feature list](https://github.com/jgoerner/SportsPrediction/wiki/Feature-List#actual-feature-vector-for-model-1)). The features currently lack a distinction between "regular season" and "playoffs" (see [issue](https://github.com/jgoerner/SportsPrediction/issues/61)) - to be solved soon.

# %% [markdown]
# # Imports

# %%
# Necessary to import custom modules
import os
from pathlib import Path
os.chdir("/home/jovyan/work")

import pandas as pd


from src.features import get_feature

# %% [markdown]
# # Processing
# The overall processing consists of two steps:
# 1. get all features per team (e.g. wins as home team in 2016/2017), ...
# 2. get all games in the format team_home|team_guest|score_home|score_guest|home_win

# %% [markdown]
# ### Features per team

# %%
# construct wins
df_wins_home = get_feature("wins_per_team_per_season_as_home")
df_wins_guest = get_feature("wins_per_team_per_season_as_guest")
df_wins = df_wins_home.merge(df_wins_guest)

# construct losses
df_losses_home = get_feature("losses_per_team_per_season_as_home")
df_losses_guest = get_feature("losses_per_team_per_season_as_guest")
df_losses = df_losses_home.merge(df_losses_guest)

# construct margins
df_margin_home = get_feature("average_score_margin_regular_season_as_home")
df_margin_guest = get_feature("average_score_margin_regular_season_as_guest")
df_margin = df_margin_home.merge(df_margin_guest)

# combine, pivot and rename
df_merged = df_wins.merge(df_losses).merge(df_margin).pivot(index="team", columns="season")
df_merged.columns = ["_".join(col) for col in df_merged.columns.values]
df_merged.head()
# Out:
#                    wins_as_home_2015/2016  wins_as_home_2016/2017  \
# team
# Atlanta Hawks                          30                      25
# Boston Celtics                         30                      35
# Brooklyn Nets                          14                      13
# Charlotte Hornets                      32                      22
# Chicago Bulls                          26                      25
#
#                    wins_as_home_2017/2018  wins_as_guest_2015/2016  \
# team
# Atlanta Hawks                          16                       22
# Boston Celtics                         37                       20
# Brooklyn Nets                          15                        7
# Charlotte Hornets                      21                       19
# Chicago Bulls                          17                       16
#
#                    wins_as_guest_2016/2017  wins_as_guest_2017/2018  \
# team
# Atlanta Hawks                           20                        8
# Boston Celtics                          27                       29
# Brooklyn Nets                            7                       13
# Charlotte Hornets                       14                       15
# Chicago Bulls                           18                       10
#
#                    losses_as_home_2015/2016  losses_as_home_2016/2017  \
# team
# Atlanta Hawks                            16                        19
# Boston Celtics                           14                        16
# Brooklyn Nets                            27                        28
# Charlotte Hornets                        12                        19
# Chicago Bulls                            15                        19
#
#                    losses_as_home_2017/2018  losses_as_guest_2015/2016  \
# team
# Atlanta Hawks                            25                         24
# Boston Celtics                           15                         24
# Brooklyn Nets                            26                         34
# Charlotte Hornets                        20                         26
# Chicago Bulls                            24                         25
#
#                    losses_as_guest_2016/2017  losses_as_guest_2017/2018  \
# team
# Atlanta Hawks                             24                         33
# Boston Celtics                            22                         20
# Brooklyn Nets                             34                         28
# Charlotte Hornets                         27                         26
# Chicago Bulls                             26                         31
#
#                    score_margin_as_home_2015/2016  \
# team
# Atlanta Hawks                           11.934783
# Boston Celtics                          10.977273
# Brooklyn Nets                           10.243902
# Charlotte Hornets                       11.136364
# Chicago Bulls                            8.756098
#
#                    score_margin_as_home_2016/2017  \
# team
# Atlanta Hawks                           11.500000
# Boston Celtics                          11.137255
# Brooklyn Nets                           10.707317
# Charlotte Hornets                       11.024390
# Chicago Bulls                           12.136364
#
#                    score_margin_as_home_2017/2018  \
# team
# Atlanta Hawks                           12.292683
# Boston Celtics                          10.115385
# Brooklyn Nets                            9.585366
# Charlotte Hornets                       12.560976
# Chicago Bulls                           10.926829
#
#                    score_margin_as_guest_2015/2016  \
# team
# Atlanta Hawks                            11.500000
# Boston Celtics                           10.636364
# Brooklyn Nets                            11.243902
# Charlotte Hornets                        11.755556
# Chicago Bulls                            10.975610
#
#                    score_margin_as_guest_2016/2017  \
# team
# Atlanta Hawks                            10.750000
# Boston Celtics                            9.571429
# Brooklyn Nets                            13.682927
# Charlotte Hornets                         9.365854
# Chicago Bulls                            12.022727
#
#                    score_margin_as_guest_2017/2018
# team
# Atlanta Hawks                             9.439024
# Boston Celtics                            9.244898
# Brooklyn Nets                            10.878049
# Charlotte Hornets                        10.975610
# Chicago Bulls                            13.512195

# %% [markdown]
# ### All games with score

# %%
df_games = get_feature("all_games")
df_games.head()
# Out:
#       season            team_home       team_guest  score_home  score_guest  \
# 0  2017/2018  Cleveland Cavaliers  Toronto Raptors         128           93
# 1  2017/2018  Cleveland Cavaliers  Toronto Raptors         105          103
# 2  2017/2018   Washington Wizards  Toronto Raptors          92          102
# 3  2017/2018   Washington Wizards  Toronto Raptors         106           98
# 4  2017/2018   Washington Wizards  Toronto Raptors         122          103
#
#    home_win
# 0         1
# 1         1
# 2         0
# 3         1
# 4         1

# %% [markdown]
# ### Final merging

# %%
# merge meta information about home and guest team
df_final = df_games.merge(
    df_merged,
    left_on="team_home",
    right_index=True
).merge(
    df_merged,
    left_on="team_guest",
    right_index=True,
    suffixes=("_home", "_guest")
)
df_final.head()
# Out:
#        season            team_home       team_guest  score_home  score_guest  \
# 0   2017/2018  Cleveland Cavaliers  Toronto Raptors         128           93
# 1   2017/2018  Cleveland Cavaliers  Toronto Raptors         105          103
# 7   2017/2018  Cleveland Cavaliers  Toronto Raptors         112          106
# 9   2017/2018  Cleveland Cavaliers  Toronto Raptors         132          129
# 46  2016/2017  Cleveland Cavaliers  Toronto Raptors         125          103
#
#     home_win  wins_as_home_2015/2016_home  wins_as_home_2016/2017_home  \
# 0          1                           42                           37
# 1          1                           42                           37
# 7          1                           42                           37
# 9          1                           42                           37
# 46         1                           42                           37
#
#     wins_as_home_2017/2018_home  wins_as_guest_2015/2016_home  \
# 0                            37                            31
# 1                            37                            31
# 7                            37                            31
# 9                            37                            31
# 46                           37                            31
#
#                     ...                    losses_as_home_2017/2018_guest  \
# 0                   ...                                                 9
# 1                   ...                                                 9
# 7                   ...                                                 9
# 9                   ...                                                 9
# 46                  ...                                                 9
#
#     losses_as_guest_2015/2016_guest  losses_as_guest_2016/2017_guest  \
# 0                                24                               21
# 1                                24                               21
# 7                                24                               21
# 9                                24                               21
# 46                               24                               21
#
#     losses_as_guest_2017/2018_guest  score_margin_as_home_2015/2016_guest  \
# 0                                20                              9.423077
# 1                                20                              9.423077
# 7                                20                              9.423077
# 9                                20                              9.423077
# 46                               20                              9.423077
#
#     score_margin_as_home_2016/2017_guest  \
# 0                              11.891304
# 1                              11.891304
# 7                              11.891304
# 9                              11.891304
# 46                             11.891304
#
#     score_margin_as_home_2017/2018_guest  \
# 0                              12.021739
# 1                              12.021739
# 7                              12.021739
# 9                              12.021739
# 46                             12.021739
#
#     score_margin_as_guest_2015/2016_guest  \
# 0                                   12.12
# 1                                   12.12
# 7                                   12.12
# 9                                   12.12
# 46                                  12.12
#
#     score_margin_as_guest_2016/2017_guest  \
# 0                               10.108696
# 1                               10.108696
# 7                               10.108696
# 9                               10.108696
# 46                              10.108696
#
#     score_margin_as_guest_2017/2018_guest
# 0                               10.869565
# 1                               10.869565
# 7                               10.869565
# 9                               10.869565
# 46                              10.869565
#
# [5 rows x 42 columns]

# %% [markdown]
# # Persistence

# %%
p = Path("./data/features")
if not p.exists():
    p.mkdir(parents=True)
df_final.to_csv("./data/features/first_iteration.csv", index=False)
