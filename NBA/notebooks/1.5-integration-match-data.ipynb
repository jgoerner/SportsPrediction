# %%
# Necessary to import custom modules
import os
os.chdir("/home/jovyan/work")

import pandas as pd

from src.utils import init_connection
from src.models import Team, Arena, Game, Date, Season

# %%
for _, row in df_arenas.iterrows():
